# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from ultralytics import YOLO

model = YOLO("yolov8x-seg.pt")

results = model.train(
    batch=8,
    device=0,
    data="data.yaml",
    epochs=50,
    imgsz=400,
)
# Out:
# Ultralytics YOLOv8.0.121  Python-3.11.4 torch-2.1.0.dev20230621+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 Ti, 12282MiB)
# ...
